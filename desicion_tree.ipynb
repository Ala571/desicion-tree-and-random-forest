# %%
#importing relevant libraries
from sklearn.model_selection import train_test_split
from sklearn import tree   
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score


#Importing our dataset from csv file
import pandas as pd 
dataset=pd.read_csv("titanic-passengers.csv", sep=";")

#Preprocessing our data
def preprocess_data(new_data):
    new_data['Age'].fillna(new_data['Age'].mean(),inplace=True)
    new_data.replace({'Sex':{'male': 1,'female':0}},inplace=True)
    new_data['Cabin']=new_data.Cabin.fillna('G6')
    new_data.replace({'Survived':{'Yes': 1,'No':0}},inplace=True)
    return new_data

data=preprocess_data(dataset)
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 0            343         0       2  ...  13.0000     G6         S
# 1             76         0       3  ...   7.6500  F G73         S
# 2            641         0       3  ...   7.8542     G6         S
# 3            568         0       3  ...  21.0750     G6         S
# 4            672         0       1  ...  52.0000    B71         S
# ..           ...       ...     ...  ...      ...    ...       ...
# 886           10         1       2  ...  30.0708     G6         C
# 887           61         0       3  ...   7.2292     G6         C
# 888          535         0       3  ...   8.6625     G6         S
# 889          102         0       3  ...   7.8958     G6         S
# 890          428         1       2  ...  26.0000     G6         S
#
# [891 rows x 12 columns]

# %%
x=data.drop(["Survived", "Name", "Cabin", "Ticket", "Embarked"], axis=1)
y= data["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
clf = tree.DecisionTreeClassifier()  
clf.fit(x_train, y_train)   #fitting our model
y_pred=clf.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7877094972067039

# %%
import graphviz

dot_data=tree.export_graphviz(clf,out_file=None)
graph=graphviz.Source(dot_data)
graph.render("data")
graph

# %%
data.replace({'Embarked':{'S': 1,'C':0,'Q':2}},inplace=True)

data=data.dropna(axis=0,how='any')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  ...     Fare  Cabin  Embarked
# 0            343         0       2  ...  13.0000     G6       1.0
# 1             76         0       3  ...   7.6500  F G73       1.0
# 2            641         0       3  ...   7.8542     G6       1.0
# 3            568         0       3  ...  21.0750     G6       1.0
# 4            672         0       1  ...  52.0000    B71       1.0
# ..           ...       ...     ...  ...      ...    ...       ...
# 886           10         1       2  ...  30.0708     G6       0.0
# 887           61         0       3  ...   7.2292     G6       0.0
# 888          535         0       3  ...   8.6625     G6       1.0
# 889          102         0       3  ...   7.8958     G6       1.0
# 890          428         1       2  ...  26.0000     G6       1.0
#
# [889 rows x 12 columns]

# %%
x=data.drop(["Survived", "Name", "Cabin", "Ticket","Fare"], axis=1)
y= data["Survived"]

#splitting data
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.20,random_state=10)

#applying tree algorithm
clf = tree.DecisionTreeClassifier()  
clf.fit(x_train, y_train)   #fitting our model
y_pred=clf.predict(x_test)   # evaluating our model
print("score:{}".format(accuracy_score(y_test, y_pred)))
# Out:
# score:0.7471910112359551

# %%
import graphviz

dot_data=tree.export_graphviz(clf,out_file=None)
graph=graphviz.Source(dot_data)
graph.render("data")
graph

# %%
from sklearn.ensemble import RandomForestClassifier #Importing Random Forest Classifier
from sklearn import metrics  # Importing metrics to test accuracy
clf=RandomForestClassifier(n_estimators=80)  
clf.fit(x_train, y_train)  #Training our model
y_pred=clf.predict(x_test)  #testing our model
print("Accuracy:", metrics.accuracy_score(y_test, y_pred))  #Measuring the accuracy of our model
# Out:
# Accuracy: 0.7808988764044944
